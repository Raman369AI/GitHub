# %% [markdown]
# <a href="https://colab.research.google.com/github/Raman369AI/GitHub/blob/master/pathlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path

# %%
Path.home()
# Out:
# PosixPath('/root')

# %%
p = Path('.')

# %%
p.expanduser()
# Out:
# PosixPath('.')

# %%
Path('~./sample_data').expanduser()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1236905387.py in <cell line: 0>()
# ----> 1 Path.expanduser('~./sample_data')
#
# /usr/lib/python3.12/pathlib.py in expanduser(self)
#    1400         (as returned by os.path.expanduser)
#    1401         """
# -> 1402         if (not (self.drive or self.root) and
#    1403             self._tail and self._tail[0][:1] == '~'):
#    1404             homedir = self._flavour.expanduser(self._tail[0])
#
# AttributeError: 'str' object has no attribute 'drive'

# %%
Path(".").absolute()
# Out:
# PosixPath('/content')

# %%
Path("./sample_data").absolute()
# Out:
# PosixPath('/content/sample_data')

# %%
import pandas as pd
pd.read_csv(Path("./sample_data")/"california_housing_train.csv")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
p = Path('./sample_data')
[x for x in p.iterdir()]
# Out:
# [PosixPath('sample_data/README.md'),
#  PosixPath('sample_data/anscombe.json'),
#  PosixPath('sample_data/mnist_train_small.csv'),
#  PosixPath('sample_data/california_housing_test.csv'),
#  PosixPath('sample_data/california_housing_train.csv'),
#  PosixPath('sample_data/mnist_test.csv')]

# %%
list(p.glob('**/*.csv'))
# Out:
# [PosixPath('sample_data/mnist_train_small.csv'),
#  PosixPath('sample_data/california_housing_test.csv'),
#  PosixPath('sample_data/california_housing_train.csv'),
#  PosixPath('sample_data/mnist_test.csv')]

# %%
p = Path('.')/'sample_data'
p.resolve()
# Out:
# PosixPath('/content/sample_data')

# %%
p.exists()
# Out:
# True

# %%
p.is_dir()
# Out:
# True

# %% [markdown]
# # Pure Paths
# Path handling operations and they dont actually access  a filesystem.
#
# 3 ways to access these classes:

# %%
from pathlib import PurePath, PureWindowsPath, PurePosixPath

# %% [markdown]
# purepaths have no os level operations they are merely strings so methods like resolve dont work and empty method also works

# %%
p = PurePath('//etc')

# %%
len('')
# Out:
# 0

# %%
None or False
# Out:
# False

# %%
p = PureWindowsPath('./sample_data')

# %%
def recursion(n:int):
    if n == 0:
        return 1
    else:
        return n*recursion(n-1)

# %%
recursion(5)
# Out:
# 120

# %%
for i in items.iterdir():
    print(i)

# %%
p.drive
# Out:
# ''

# %%
p.root
# Out:
# ''

# %%
PurePosixPath('./sample_data').anchor
# Out:
# ''

# %%
p.root
# Out:
# '//'

# %%
p.anchor
# Out:
# '//'

# %%
p = Path('mylink')

# %%
p
# Out:
# PosixPath('mylink')

# %%
p = Path('.')

# %%
with p.open() as f:
  print(f.readline())
# Out:
# This directory includes a few sample datasets to get you started.

# %%
p.write_text('hello world')
# Out:
# 11

# %%
p.read_text()
# Out:
# 'hello world'

# %%
p.walk()
# Out:
# <generator object Path.walk at 0x7c61ff11d1c0>

# %%
p = Path('mylink')

# %%
p.symlink_to('setup.py')

# %%
p.resolve()
# Out:
# PosixPath('/content/setup.py')

# %%
lis = [1,2,3,4,5]

# %%
x = lis

# %%
x[2] = 4

# %%
lis
# Out:
# [1, 2, 4, 4, 5]

# %%
y = x.copy()

# %%
y[2] = 3

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
x
# Out:
# [1, 2, 4, 4, 5]

# %%
from numpy import array
array = array([1,2,3,4,5])

# %%
from array import array
array = array('i',[1,2,3,4,5])

# %%
array[0]
# Out:
# 1

# %%
y[0]
# Out:
# 1

# %%
s= 'raman'

# %%
s[::-1]
# Out:
# 'namar'
