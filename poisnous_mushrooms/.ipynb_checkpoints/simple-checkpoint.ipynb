# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mushrooms = pd.read_csv("C://Users//raman//Downloads//train.csv")

# %%
mushrooms.head()
# Out:
#    id class  cap-diameter cap-shape cap-surface cap-color  \
# 0   0     e          8.80         f           s         u
# 1   1     p          4.51         x           h         o
# 2   2     e          6.94         f           s         b
# 3   3     e          3.88         f           y         g
# 4   4     e          5.85         x           l         w
#
#   does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                    f               a            c          w  ...
# 1                    f               a            c          n  ...
# 2                    f               x            c          w  ...
# 3                    f               s          NaN          g  ...
# 4                    f               d          NaN          w  ...
#
#    stem-root  stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0        NaN           NaN          w       NaN        NaN        f         f
# ...

# %%
for i in mushrooms.columns:
    print(i)
    mushrooms[i].value_counts()
# Out:
# id
# class
# cap-diameter
# cap-shape
# cap-surface
# cap-color
# does-bruise-or-bleed
# gill-attachment
# gill-spacing
# gill-color
# stem-height
# stem-width
# stem-root
# stem-surface
# stem-color
# veil-type
# veil-color
# has-ring
# ring-type
# spore-print-color
# habitat
# season

# %%
mushrooms.columns
# Out:
# Index(['id', 'class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')

# %%
mushrooms['class'].unique()
# Out:
# array(['e', 'p'], dtype=object)

# %%
mushrooms['cap-diameter'].astype(float)
# Out:
# 0          8.80
# 1          4.51
# 2          6.94
# 3          3.88
# 4          5.85
#            ...
# 1048570    3.33
# 1048571    5.91
# 1048572    4.20
# 1048573    7.54
# 1048574    8.57
# Name: cap-diameter, Length: 1048575, dtype: float64

# %%
mushrooms['cap-diameter']
# Out:
# 0          8.80
# 1          4.51
# 2          6.94
# 3          3.88
# 4          5.85
#            ...
# 1048570    3.33
# 1048571    5.91
# 1048572    4.20
# 1048573    7.54
# 1048574    8.57
# Name: cap-diameter, Length: 1048575, dtype: float64

# %%
mushrooms['cap-shape'].value_counts()
# Out:
# cap-shape
# x            482903
# f            227455
# s            122816
# b            107605
# o             36527
# p             35902
# c             35196
# d                25
# e                13
# w                13
# t                12
# r                12
# y                11
# g                11
# n                11
# z                 9
# l                 7
# a                 7
# u                 4
# 24.16             1
# 8                 1
# 6 x               1
# ring-type         1
# m                 1
# 21.56             1
# 10.13             1
# is p              1
# i                 1
# 2.85              1
# 3.6               1
# 4.22              1
# is s              1
# 3.55              1
# 7 x               1
# 5 f               1
# 19.29             1
# k                 1
# 7.43              1
# Name: count, dtype: int64

# %% [markdown]
# #Data Cleaning
# The code is values not given would not be able to check the same.
# When a column of pandas is addressed it can be treated as series and any condition would check the index as it is akin to a dictionary, use values instead.

# %%
mushrooms['gill-spacing'].unique()
# Out:
# array(['c', nan, 'd', 'f', 'x', 'b', 'a', '3.61', '2.69', 'k', '4.8', 'e',
#        'y', 'class', 's', '9.01', 'p', '3.92', '5.22', '6.67', '4.04',
#        't'], dtype=object)

# %%
mushrooms['stem-color'].value_counts()
# Out:
# stem-color
# w                    402925
# n                    337111
# y                    125865
# g                     44181
# o                     37705
# e                     34839
# u                     22483
# p                     18466
# k                     11303
# r                      7560
# l                      3352
# b                      2507
# f                       190
# t                        16
# s                        13
# a                        11
# i                         8
# m                         4
# z                         4
# x                         4
# h                         2
# d                         2
# is n                      1
# 7.33                      1
# c                         1
# e n                       1
# 1.75                      1
# 3.13                      1
# 33.52                     1
# ring-type                 1
# 2.78                      1
# spore-print-color         1
# ...

# %%
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        print(i)
        print(mushrooms[i].unique())
# Out:
# class
# ['e' 'p']
# cap-shape
# ['f' 'x' 'p' 'b' 'o' 'c' 's' 'd' 'e' 'n' nan 'w' 'k' 'l' '19.29' '5 f' 't'
#  'g' 'z' 'a' '2.85' '7 x' 'r' 'u' '3.55' 'is s' 'y' '4.22' '3.6' '21.56'
#  'i' '6 x' '24.16' '8' 'm' 'ring-type' '10.13' 'is p' '7.43']
# cap-surface
# ['s' 'h' 'y' 'l' 't' 'e' 'g' nan 'd' 'i' 'w' 'k' '15.94' 'f' 'n' 'r' 'o'
#  'a' 'u' 'z' '2.7' 'does l' '5.07' 'p' 'b' 'm' 'cap-diameter' '1.43' 'x'
#  '7.14' 'c' 'is h' 'does t' '0.85' '6.57' '12.79' '6.45' '4.66' '23.18'
#  '3.06' '16.39' '4.21' 'veil-color' '11.78' '8.1' 'has-ring' 'does h'
#  '1.42' 'class' 'has h' 'does None']
# cap-color
# ['u' 'o' 'b' 'g' 'w' 'n' 'e' 'y' 'r' 'p' 'k' 'l' 'i' 'h' 'd' 's' 'a' 'f'
#  '2.05' 'season' 'c' 'x' '13' '7.72' 'm' 'z' '6.76' '7.15' 't' 'ring-type'
#  nan 'class' '12.89' '8.83' '24.75' '22.38' '1.51' '10.1' '17.94' '3.57'
#  'does n' '4.89' '6.2' '21.53' '6.41' '4.98' '3.95']
# does-bruise-or-bleed
# ['f' 't' 'd' 'has-ring' 'w' 'o' 'b' 'x' 'p' nan 'g' 'y' 'r' 'a' 'l' 'i'
# ...

# %%
# Assuming 'mushrooms' is your DataFrame
i_list = {}
for i in mushrooms.columns:
    if mushrooms[i].dtype == object :
        i_list[i] = mushrooms[i].value_counts().to_dict()
        print(i_list[i])
# Out:
# {'p': 574086, 'e': 474489}
# {'x': 482903, 'f': 227455, 's': 122816, 'b': 107605, 'o': 36527, 'p': 35902, 'c': 35196, 'd': 25, 'e': 13, 'w': 13, 't': 12, 'r': 12, 'y': 11, 'g': 11, 'n': 11, 'z': 9, 'l': 7, 'a': 7, 'u': 4, '24.16': 1, '8': 1, '6 x': 1, 'ring-type': 1, 'm': 1, '21.56': 1, '10.13': 1, 'is p': 1, 'i': 1, '2.85': 1, '3.6': 1, '4.22': 1, 'is s': 1, '3.55': 1, '7 x': 1, '5 f': 1, '19.29': 1, 'k': 1, '7.43': 1}
# {'t': 155187, 's': 129176, 'y': 110380, 'h': 95531, 'g': 88347, 'd': 69905, 'k': 43148, 'e': 40371, 'i': 38399, 'w': 37124, 'l': 15108, 'n': 33, 'p': 25, 'f': 22, 'a': 18, 'o': 17, 'm': 13, 'u': 12, 'r': 11, 'x': 8, 'b': 7, 'c': 6, 'z': 5, 'has-ring': 2, 'does h': 1, '1.42': 1, 'class': 1, '4.66': 1, '8.1': 1, 'has h': 1, '11.78': 1, 'veil-color': 1, '4.21': 1, '16.39': 1, '3.06': 1, '23.18': 1, 'cap-diameter': 1, '6.45': 1, '12.79': 1, '6.57': 1, '0.85': 1, 'does t': 1, 'is h': 1, '7.14': 1, '1.43': 1, '5.07': 1, 'does l': 1, '2.7': 1, '15.94': 1, 'does None': 1}
# ...

# %%
filtered_i_list = {col: {value: count for value, count in counts.items() if count >= 10} for col, counts in i_list.items()}

print(filtered_i_list)
# Out:
# {'class': {'p': 574086, 'e': 474489}, 'cap-shape': {'x': 482903, 'f': 227455, 's': 122816, 'b': 107605, 'o': 36527, 'p': 35902, 'c': 35196, 'd': 25, 'e': 13, 'w': 13, 't': 12, 'r': 12, 'y': 11, 'g': 11, 'n': 11}, 'cap-surface': {'t': 155187, 's': 129176, 'y': 110380, 'h': 95531, 'g': 88347, 'd': 69905, 'k': 43148, 'e': 40371, 'i': 38399, 'w': 37124, 'l': 15108, 'n': 33, 'p': 25, 'f': 22, 'a': 18, 'o': 17, 'm': 13, 'u': 12, 'r': 11}, 'cap-color': {'n': 457296, 'y': 130308, 'w': 127726, 'g': 70879, 'e': 66235, 'o': 60060, 'p': 31132, 'r': 26260, 'u': 24562, 'b': 20642, 'k': 20031, 'l': 13315, 'd': 20, 'f': 19, 'h': 11}, 'does-bruise-or-bleed': {'f': 864524, 't': 184013}, 'gill-attachment': {'a': 217299, 'd': 198093, 'x': 121386, 'e': 101561, 's': 99581, 'p': 93886, 'f': 40255, 'c': 26, 't': 18, 'u': 16, 'k': 14, 'g': 12, 'w': 11, 'b': 10}, 'gill-spacing': {'c': 448920, 'd': 136998, 'f': 40078, 'e': 11, 'a': 10}, 'gill-color': {'w': 313049, 'n': 182928, 'y': 158279, 'p': 115654, 'g': 71
# ...

# %%
for i in filtered_i_list:
    mushrooms[i] = mushrooms[i].apply(lambda x: x if x in filtered_i_list[i].keys() else np.nan)

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x         NaN         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
for i in mushrooms.columns:
    print(i)
    print(mushrooms[i].unique())
# Out:
# id
# [      0       1       2 ... 1048572 1048573 1048574]
# class
# ['e' 'p']
# cap-diameter
# [ 8.8   4.51  6.94 ... 27.83 21.06 44.94]
# cap-shape
# ['f' 'x' 'p' 'b' 'o' 'c' 's' 'd' 'e' 'n' nan 'w' 't' 'g' 'r' 'y']
# cap-surface
# ['s' 'h' 'y' 'l' 't' 'e' 'g' nan 'd' 'i' 'w' 'k' 'f' 'n' 'r' 'o' 'a' 'u'
#  'p' 'm']
# cap-color
# ['u' 'o' 'b' 'g' 'w' 'n' 'e' 'y' 'r' 'p' 'k' 'l' nan 'h' 'd' 'f']
# does-bruise-or-bleed
# ['f' 't' nan]
# gill-attachment
# ['a' 'x' 's' 'd' 'e' nan 'f' 'p' 'b' 'g' 'u' 't' 'c' 'w' 'k']
# gill-spacing
# ['c' nan 'd' 'f' 'a' 'e']
# gill-color
# ['w' 'n' 'g' 'k' 'y' 'f' 'p' 'o' 'b' 'u' 'e' 'r' 'd' 't' nan 's' 'l']
# stem-height
# [ 4.51  4.79  6.85 ... 21.21 24.67 25.7 ]
# stem-width
# [15.39  6.48  9.93 ... 74.37 71.4  65.75]
# stem-root
# [nan 'b' 'c' 'r' 's' 'f']
# stem-surface
# [nan 'y' 's' 't' 'g' 'h' 'k' 'i' 'f' 'd' 'x' 'w' 'n' 'e' 'p']
# stem-color
# ['w' 'o' 'n' 'y' 'e' 'u' 'p' 'f' 'g' 'r' 'k' 'l' 'b' nan 't' 'a' 's']
# veil-type
# [nan 'u']
# ...

# %%
for i in filtered_i_list:
    l = list(filtered_i_list.keys())

# %%
l
# Out:
# ['class',
#  'cap-shape',
#  'cap-surface',
#  'cap-color',
#  'does-bruise-or-bleed',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-color',
#  'stem-root',
#  'stem-surface',
#  'stem-color',
#  'veil-type',
#  'veil-color',
#  'has-ring',
#  'ring-type',
#  'spore-print-color',
#  'habitat',
#  'season']

# %%
mushrooms_cleaned = mushrooms.dropna(how = 'any', axis = 0,subset = l, ignore_index=True)

# %%
mushrooms_cleaned
# Out:
# Empty DataFrame
# Columns: [id, class, cap-diameter, cap-shape, cap-surface, cap-color, does-bruise-or-bleed, gill-attachment, gill-spacing, gill-color, stem-height, stem-width, stem-root, stem-surface, stem-color, veil-type, veil-color, has-ring, ring-type, spore-print-color, habitat, season]
# Index: []
#
# [0 rows x 22 columns]

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x         NaN         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms.isna().sum()
# Out:
# id                           0
# class                        0
# cap-diameter                 1
# cap-shape                   63
# cap-surface             225748
# cap-color                   79
# does-bruise-or-bleed        38
# gill-attachment         176407
# gill-spacing            422558
# gill-color                  88
# stem-height                  0
# stem-width                   0
# stem-root               927445
# stem-surface            666600
# stem-color                  48
# veil-type               995081
# veil-color              922234
# has-ring                    47
# ring-type                43275
# spore-print-color       958869
# habitat                     64
# season                       0
# dtype: int64

# %%
mushrooms['id'].astype(int)
# Out:
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
#             ...
# 1048570    1048570
# 1048571    1048571
# 1048572    1048572
# 1048573    1048573
# 1048574    1048574
# Name: id, Length: 1048575, dtype: int32

# %%
columns_float = []
for i in mushrooms.columns:
    if mushrooms[i].dtype != object:
        columns_float.append(i)

# %%
columns_float
# Out:
# ['id', 'cap-diameter', 'stem-height', 'stem-width']

# %%
columns_object = []
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        columns_object.append(i)

# %%
columns_object
# Out:
# ['class',
#  'cap-shape',
#  'cap-surface',
#  'cap-color',
#  'does-bruise-or-bleed',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-color',
#  'stem-root',
#  'stem-surface',
#  'stem-color',
#  'veil-type',
#  'veil-color',
#  'has-ring',
#  'ring-type',
#  'spore-print-color',
#  'habitat',
#  'season']

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x         NaN         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms[mushrooms['gill-spacing'].notna()]
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 5              5     p          4.30         x           t         n
# 6              6     e          9.65         p           y         w
# ...          ...   ...           ...       ...         ...       ...
# 1048569  1048569     e          6.58         f           s         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x         NaN         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms.isna().sum()
# Out:
# id                           0
# class                        0
# cap-diameter                 1
# cap-shape                   63
# cap-surface             225748
# cap-color                   79
# does-bruise-or-bleed        38
# gill-attachment         176407
# gill-spacing            422558
# gill-color                  88
# stem-height                  0
# stem-width                   0
# stem-root               927445
# stem-surface            666600
# stem-color                  48
# veil-type               995081
# veil-color              922234
# has-ring                    47
# ring-type                43275
# spore-print-color       958869
# habitat                     64
# season                       0
# dtype: int64

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x         NaN         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms['cap-diameter'].fillna(0, inplace = True)
# Out:
# C:\Users\raman\AppData\Local\Temp\ipykernel_6240\3488419369.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mushrooms['cap-diameter'].fillna(0, inplace = True)

# %%
mushrooms.fillna('Missing',inplace = True)

# %%
poisnous = mushrooms[mushrooms['class']=='p']

# %%
poisnous
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 1              1     p          4.51         x           h         o
# 5              5     p          4.30         x           t         n
# 7              7     p          4.55         x           e         e
# 8              8     p          7.36         f           h         e
# 14            14     p          3.91         b           t         n
# ...          ...   ...           ...       ...         ...       ...
# 1048564  1048564     p          5.94         f           t         n
# 1048566  1048566     p          5.98         x           i         e
# 1048567  1048567     p          5.32         x     Missing         w
# 1048570  1048570     p          3.33         b           t         n
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
poisnous['cap-diameter'].mean()
# Out:
# 5.6242743421717325

# %%
poisnous['cap-diameter'].median()
# Out:
# 4.68

# %%
edible = mushrooms[mushrooms['class']=='e']

# %%
edible['cap-diameter'].mean()
# Out:
# 7.136056262632009

# %%
edible['cap-diameter'].median()
# Out:
# 6.52

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x     Missing         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms.to_csv('mushrooms_powerbi')

# %%
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x     Missing         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms.dtypes
# Out:
# id                        int64
# class                    object
# cap-diameter            float64
# cap-shape                object
# cap-surface              object
# cap-color                object
# does-bruise-or-bleed     object
# gill-attachment          object
# gill-spacing             object
# gill-color               object
# stem-height             float64
# stem-width              float64
# stem-root                object
# stem-surface             object
# stem-color               object
# veil-type                object
# veil-color               object
# has-ring                 object
# ring-type                object
# spore-print-color        object
# habitat                  object
# season                   object
# dtype: object

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x     Missing         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as pyo

# Assuming mushrooms is your DataFrame
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        layout = go.Layout(
            title=f'Poisonous/edible - {i}',
            xaxis=dict(title=f'Feature name: {i}'),
            yaxis=dict(title='Count'),
            hovermode='closest',
            autosize=True
        )

        # Get value counts for edible and poisonous classes
        edible_counts = mushrooms[mushrooms['class'] == 'e'][i].value_counts()
        poisonous_counts = mushrooms[mushrooms['class'] == 'p'][i].value_counts()

        # Align the indices of both Series
        all_values = edible_counts.index.union(poisonous_counts.index)
        edible_counts = edible_counts.reindex(all_values, fill_value=0)
        poisonous_counts = poisonous_counts.reindex(all_values, fill_value=0)

        trace0 = go.Bar(x=all_values, y=edible_counts, name='Edible', marker={'color': 'blue'})
        trace1 = go.Bar(x=all_values, y=poisonous_counts, name='Poisonous', marker={'color': 'red'})

        data = [trace0, trace1]
        fig = go.Figure(data=data, layout=layout)
        pyo.plot(fig)

# %%
import pandas as pd
import plotly.graph_objs as go
import plotly.offline as pyo

# Assuming mushrooms is your DataFrame
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        layout = go.Layout(
            title=f'Poisonous/edible - {i}',
            xaxis=dict(title=f'Feature name: {i}'),
            yaxis=dict(title='Count'),
            hovermode='closest',
            autosize=True
        )
        
        # Get value counts for edible and poisonous classes
        edible_counts = mushrooms[mushrooms['class'] == 'e'][i].value_counts()
        poisonous_counts = mushrooms[mushrooms['class'] == 'p'][i].value_counts()
        
        # Align the indices of both Series
        all_values = edible_counts.index.union(poisonous_counts.index)
        edible_counts = edible_counts.reindex(all_values, fill_value=0)
        poisonous_counts = poisonous_counts.reindex(all_values, fill_value=0)
        
        trace0 = go.Bar(x=all_values, y=edible_counts, name='Edible', marker={'color': 'blue'})
        trace1 = go.Bar(x=all_values, y=poisonous_counts, name='Poisonous', marker={'color': 'red'})
        
        data = [trace0, trace1]
        fig = go.Figure(data=data, layout=layout)
        pyo.plot(fig)

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x     Missing         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x     Missing         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
Y_train = mushrooms['class'].apply(lambda x: 1 if x=='p' else 0)
X_train = mushrooms.iloc[:,2:]

# %%
X_train
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0                8.80         f           s         u                    f
# 1                4.51         x           h         o                    f
# 2                6.94         f           s         b                    f
# 3                3.88         f           y         g                    f
# 4                5.85         x           l         w                    f
# ...               ...       ...         ...       ...                  ...
# 1048570          3.33         b           t         n                    f
# 1048571          5.91         f           s         n                    f
# 1048572          4.20         x     Missing         n                    f
# 1048573          7.54         f           s         u                    f
# 1048574          8.57         s           t         p                    t
#
# ...

# %%
from sklearn.preprocessing import TargetEncoder

# %%
enc_auto = TargetEncoder(smooth="auto")

# %%
X_trans = enc_auto.fit_transform(X_train, Y_train)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_trans, Y_train, test_size=0.3, random_state=42)#%%

import lightgbm as lgb

# %%
train_data = lgb.Dataset(X_trans, label=Y_train)

# %%
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# %%
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',  # Gradient Boosting Decision Tree
    'num_leaves': 31,         # Number of leaves in one tree
    'learning_rate': 0.05,
    'feature_fraction': 0.9   # Randomly select a fraction of features to build each tree
}

# %%
lgb_model = lgb.train(
    params,
    train_data,
    num_boost_round=20,
    valid_sets=[train_data, test_data]
)
# Out:
# [LightGBM] [Info] Number of positive: 574086, number of negative: 474489
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037143 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1464
# [LightGBM] [Info] Number of data points in the train set: 1048575, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.547492 -> initscore=0.190541
# [LightGBM] [Info] Start training from score 0.190541

# %%
y_pred_prob = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)

# %%
y_pred = [1 if x > 0.5 else 0 for x in y_pred_prob]

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_prob)

print(f"Accuracy: {accuracy}")
print(f"ROC AUC: {roc_auc}")
# Out:
# Accuracy: 0.9239031957606024
# ROC AUC: 0.972494104250793

# %%
cv_results = lgb.cv(
    params,
    train_data,
    nfold = 5,
    num_boost_round=100,  # Number of boosting rounds  # Number of folds
    stratified=True,  # Stratified folds (ensures even distribution of labels)
    shuffle=True,  # Shuffle data before splitting into folds
    metrics='binary_error',  # Evaluation metric  # Stop early if no improvement
    
)

# Extract best number of boosting rounds
# Out:
# [LightGBM] [Info] Number of positive: 459269, number of negative: 379591
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044331 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1464
# [LightGBM] [Info] Number of data points in the train set: 838860, number of used features: 20
# [LightGBM] [Info] Number of positive: 459269, number of negative: 379591
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038582 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1464
# [LightGBM] [Info] Number of data points in the train set: 838860, number of used features: 20
# [LightGBM] [Info] Number of positive: 459269, number of negative: 379591
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055397 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# ...

# %%
from sklearn.metrics import cohen_kappa_score

# %%
accuracy = cohen_kappa_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8459743269752861

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 1048570  1048570     p          3.33         b           t         n
# 1048571  1048571     e          5.91         f           s         n
# 1048572  1048572     e          4.20         x     Missing         n
# 1048573  1048573     e          7.54         f           s         u
# 1048574  1048574     p          8.57         s           t         p
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
mushrooms.stack().reset_index()
# Out:
#           level_0            level_1        0
# 0               0                 id        0
# 1               0              class        e
# 2               0       cap-diameter      8.8
# 3               0          cap-shape        f
# 4               0        cap-surface        s
# ...           ...                ...      ...
# 23068645  1048574           has-ring        t
# 23068646  1048574          ring-type        f
# 23068647  1048574  spore-print-color  Missing
# 23068648  1048574            habitat        d
# 23068649  1048574             season        a
#
# [23068650 rows x 3 columns]

# %%
mushrooms.pivot_table(index = 'class', columns = ['season'], values = 'cap-diameter')
# Out:
# season         a         s         u         w
# class
# e       6.988062  7.953556  7.173477  7.183288
# p       5.751741  4.033535  5.333853  7.374152

# %%
mushrooms.groupby(['class','season'])['cap-diameter'].mean().unstack()
# Out:
# season         a         s         u         w
# class
# e       6.988062  7.953556  7.173477  7.183288
# p       5.751741  4.033535  5.333853  7.374152

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
x = tree.fit(X_train, y_train)

# %%
x
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(x)
# Out:
# [Text(0.5419666533572987, 0.9912280701754386, 'x[9] <= 0.551\ngini = 0.496\nsamples = 734002\nvalue = [332367, 401635]'),
#  Text(0.3248863184320348, 0.9736842105263158, 'x[3] <= 0.674\ngini = 0.482\nsamples = 363569\nvalue = [215873, 147696]'),
#  Text(0.4334264858946667, 0.9824561403508771, 'True  '),
#  Text(0.2016146235426401, 0.956140350877193, 'x[5] <= 0.36\ngini = 0.45\nsamples = 301019\nvalue = [198260.0, 102759.0]'),
#  Text(0.09381183856766173, 0.9385964912280702, 'x[13] <= 0.598\ngini = 0.264\nsamples = 94812\nvalue = [79941, 14871]'),
#  Text(0.08214881696458771, 0.9210526315789473, 'x[10] <= 0.847\ngini = 0.113\nsamples = 76846\nvalue = [72205, 4641]'),
#  Text(0.07500259658487789, 0.9035087719298246, 'x[3] <= 0.517\ngini = 0.084\nsamples = 75512\nvalue = [72195, 3317]'),
#  Text(0.06902917620635429, 0.8859649122807017, 'x[11] <= 0.703\ngini = 0.051\nsamples = 67021\nvalue = [65258, 1763]'),
# ...

# %%
plt.show()
