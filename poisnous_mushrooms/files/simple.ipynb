# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mushrooms = pd.read_csv("C://Users//raman//Desktop//train.csv")

# %%
mushrooms.shape
# Out:
# (3116945, 22)

# %%
mushrooms.columns
# Out:
# Index(['id', 'class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')

# %%
mushrooms['class'].unique()
# Out:
# array(['e', 'p'], dtype=object)

# %%
mushrooms['cap-diameter'].astype(float)
# Out:
# 0           8.80
# 1           4.51
# 2           6.94
# 3           3.88
# 4           5.85
#            ...
# 3116940     9.29
# 3116941    10.88
# 3116942     7.82
# 3116943     9.45
# 3116944     3.20
# Name: cap-diameter, Length: 3116945, dtype: float64

# %% [markdown]
# #Data Cleaning
# The code is values not given would not be able to check the same.
# When a column of pandas is addressed it can be treated as series and any condition would check the index as it is akin to a dictionary, use values instead.

# %%
# Assuming 'mushrooms' is your DataFrame
i_list = {}
for i in mushrooms.columns:
    if mushrooms[i].dtype == object :
        i_list[i] = mushrooms[i].value_counts().to_dict()
        print(i_list[i])
# Out:
# {'p': 1705396, 'e': 1411549}
# {'x': 1436026, 'f': 676238, 's': 365146, 'b': 318646, 'o': 108835, 'p': 106967, 'c': 104520, 'd': 65, 'e': 60, 'n': 41, 't': 36, 'w': 36, 'g': 34, 'y': 33, 'r': 32, 'a': 30, 'u': 27, 'z': 22, 'l': 21, 'i': 14, 'k': 13, 'h': 6, 'm': 2, '8': 2, '3.55': 2, '7 x': 2, '4.97': 2, '3.25': 1, '11.12': 1, '3 x': 1, '4.3': 1, '7.41': 1, '6.21': 1, '8.29': 1, '7.21': 1, '54.78': 1, '2.82': 1, '20.25': 1, '3.52': 1, '3.04': 1, '6.53': 1, '2.63': 1, '3.91': 1, '6.44': 1, '8.3': 1, '7.6': 1, '1.66': 1, '17.44': 1, '4.33': 1, '3.37': 1, '7.43': 1, '9.13': 1, 'ring-type': 1, '19.29': 1, '5 f': 1, '2.85': 1, 'is s': 1, '4.22': 1, '3.6': 1, '21.56': 1, '6 x': 1, '24.16': 1, '10.13': 1, 'b f': 1, 'is p': 1, '0.82': 1, '10.46': 1, '2.77': 1, '2.94': 1, '12.62': 1, '5.15': 1, '19.04': 1, '49.21': 1, '19.06': 1}
# {'t': 460777, 's': 384970, 'y': 327826, 'h': 284460, 'g': 263729, 'd': 206832, 'k': 128875, 'e': 119712, 'i': 113440, 'w': 109840, 'l': 44859, 'n': 96, 'f': 75, 'p': 59, 'u': 49, 'a': 44, 'm': 42, 'o': 39, 'r': 35, 'x': 33, 'c': 31, 'b': 18, 'z': 8, 'season': 7, 'ring-type': 4, 'class': 2, 'has-ring': 2, 'does None': 2, 'does t': 2, 'spore-print-color': 1, '4.93': 1, 'does-bruise-or-bleed': 1, '10.1': 1, '2.79': 1, 'spore-color': 1, '2.11': 1, '0.88': 1, '2.81': 1, 'is k': 1, '7.99': 1, '2.92': 1, '2.51': 1, '10.34': 1, 'is y': 1, '3.64': 1, '3.33': 1, '41.91': 1, '12.2': 1, '8.01': 1, '9.22': 1, 'is None': 1, '1.14': 1, '6.49': 1, '1.08': 1, '24.38': 1, 'veil-color': 1, '5.73': 1, '6.45': 1, '15.94': 1, '2.7': 1, 'does l': 1, '5.07': 1, 'cap-diameter': 1, '1.43': 1, '7.14': 1, 'is h': 1, '0.85': 1, '6.57': 1, '12.79': 1, '4.66': 1, '14.04': 1, '23.18': 1, '3.06': 1, '16.39': 1, '4.21': 1, '11.78': 1, '8.1': 1, 'does h': 1, '1.42': 1, 'has h': 1, '10.83': 1, '8.96': 1, '0.87': 1}
# {'n': 1359542, 'y': 386627, 'w': 379442, 'g': 210825, 'e': 197290, 'o': 178847, 'p': 91838, 'r': 78236, 'u': 73172, 'b': 61313, 'k': 59888, 'l': 39558, 'f': 53, 'd': 48, 's': 39, 'a': 30, 't': 26, 'h': 22, 'm': 14, 'x': 14, 'c': 14, 'i': 13, 'z': 10, 'ring-type': 6, 'season': 6, 'class': 5, '11.13': 2, 'does-bruise-or-bleed': 2, '3.34': 2, '2.7': 1, '8.57': 1, '17.93': 1, '2.57': 1, '11.92': 1, '3.08': 1, '2.82': 1, '4.24': 1, '17.19': 1, '20.02': 1, '7': 1, '2.9': 1, '6.36': 1, '5.91': 1, '10.56': 1, '26.89': 1, '4. n': 1, '20.62': 1, 'stem-surface': 1, '20': 1, '25.98': 1, '8.67': 1, '3.11': 1, 'does n': 1, '5.41': 1, '10.1': 1, '2.05': 1, '13': 1, '7.72': 1, '6.76': 1, '7.15': 1, '12.89': 1, '8.83': 1, '24.75': 1, '22.38': 1, '1.51': 1, '17.94': 1, '6.9': 1, '3.57': 1, '4.89': 1, '6.2': 1, '21.53': 1, '6.41': 1, '4.98': 1, '3.95': 1, '6.59': 1, '5.25': 1, 'veil-color': 1, '9.02': 1}
# {'f': 2569743, 't': 547085, 'w': 14, 'c': 11, 'h': 9, 'a': 7, 'b': 7, 'x': 7, 'y': 7, 'k': 6, 's': 6, 'e': 4, 'l': 4, 'p': 4, 'd': 4, 'g': 3, 'z': 3, 'o': 3, 'i': 2, 'n': 2, 'r': 1, 'has-ring': 1, '3.43': 1, '4.42': 1, '2.9': 1, 'u': 1}
# {'a': 646034, 'd': 589236, 'x': 360878, 'e': 301858, 's': 295439, 'p': 279110, 'f': 119953, 'c': 74, 'u': 56, 'w': 37, 't': 36, 'k': 33, 'y': 28, 'i': 25, 'm': 22, 'g': 22, 'b': 21, 'n': 20, 'o': 18, 'h': 18, 'l': 16, 'r': 10, 'z': 5, 'season': 5, '3.45': 2, '2.54': 1, '6.32': 1, '13.15': 1, '19.65': 1, '2.41': 1, '15.49': 1, '4.01': 1, '8.37': 1, 'does f': 1, '6.11': 1, '28.7': 1, '1.51': 1, '1.37': 1, '28.15': 1, '7.09': 1, '9.88': 1, '2.67': 1, '18.21': 1, '1.48': 1, '5.93': 1, '1.32': 1, '16.27': 1, '11.26': 1, '2.79': 1, 'is f': 1, '8.47': 1, '3.91': 1, 'has d': 1, '11.62': 1, '32.54': 1, 'does-bruise-or-bleed': 1, '4.64': 1, '4.77': 1, 'p p': 1, '7.92': 1, '8.79': 1, 'does None': 1, 'has f': 1, 'ring-type': 1, '16.33': 1, '10.85': 1, '20.07': 1, '2.82': 1, '7.86': 1, 'does': 1, '10.23': 1, '6.74': 1, '0.92': 1, '1': 1, 'is a': 1, '3.71': 1, '50.44': 1, '13.94': 1}
# {'c': 1331054, 'd': 407932, 'f': 119380, 'e': 24, 'a': 17, 's': 16, 'b': 12, 'x': 8, 't': 8, 'p': 7, 'k': 4, 'g': 4, 'l': 3, 'h': 3, 'r': 2, '6.67': 2, 'y': 2, '0': 2, '3.81': 1, '1.6': 1, 'n': 1, '1.88': 1, 'does f': 1, '4.09': 1, '1.36': 1, '3.24': 1, '5.55': 1, '5.42': 1, '5.7': 1, '3.62': 1, '6.4': 1, '24.38': 1, '12.27': 1, '1': 1, 'cap-surface': 1, 'w': 1, '3.57': 1, 'i': 1, '0.73': 1, '4.04': 1, '5.22': 1, '3.92': 1, '9.01': 1, 'class': 1, '4.8': 1, '2.69': 1, '3.61': 1, '55.13': 1}
# {'w': 931538, 'n': 543386, 'y': 469464, 'p': 343626, 'g': 212164, 'o': 157119, 'k': 127970, 'f': 119694, 'r': 62799, 'e': 56047, 'b': 47247, 'u': 45399, 'l': 55, 'd': 54, 't': 54, 's': 46, 'x': 35, 'c': 31, 'a': 28, 'h': 24, 'm': 16, 'z': 16, 'i': 9, 'class': 7, 'season': 7, 'ring-type': 5, 'spacing': 4, 'spore-print-color': 3, '5': 3, 'has-ring': 3, 'habitat': 2, '18.03': 2, 'e y': 1, 'is y': 1, '1.91': 1, 'does n': 1, '4.64': 1, '10.21': 1, '16.41': 1, '6.41': 1, '8.83': 1, 'veil-type': 1, 'does-bruise-or-bleed': 1, '20.44': 1, '6.4': 1, '10.07': 1, '20.6': 1, '7.59': 1, '4': 1, '0.92': 1, '18.12': 1, '3.39': 1, 'does w': 1, '3.45': 1, '8.06': 1, 'stem-root': 1, '6.19': 1, '4.49': 1, '9.46': 1, '5.01': 1, '3.4': 1, '17': 1, '8.37': 1}
# {'b': 165801, 's': 116946, 'r': 47803, 'c': 28592, 'f': 597, 'd': 24, 'y': 14, 'g': 12, 'w': 12, 'p': 12, 'k': 11, 't': 10, 'l': 10, 'n': 10, 'x': 9, 'i': 8, 'u': 8, 'a': 7, 'e': 6, 'o': 5, 'm': 4, 'h': 4, 'z': 2, '10.87': 1, '13.03': 1, '3.49': 1, 'spore-print-color': 1, '18.06': 1, '20.0': 1, '1.48': 1, '3.23': 1, '15.69': 1, '16.88': 1, '5.59': 1, '2.77': 1, '20.01': 1, '3.63': 1, '7.15': 1}
# {'s': 327610, 'y': 255500, 'i': 224346, 't': 147974, 'g': 78080, 'k': 73383, 'h': 28283, 'f': 512, 'w': 49, 'd': 48, 'e': 36, 'n': 34, 'x': 26, 'b': 23, 'c': 22, 'l': 20, 'p': 20, 'r': 20, 'u': 16, 'o': 15, 'a': 11, 'm': 7, 'season': 6, '0.0': 3, 'z': 2, 'does-bruise-or-bleed': 2, '5.56': 2, '10.48': 2, 'does s': 1, '1.03': 1, '7.45': 1, 'has h': 1, '1.94': 1, 'does None': 1, '10.93': 1, '49.46': 1, '19.35': 1, '2.68': 1, '4.74': 1, 'spore-print-color': 1, '5.35': 1, '24.12': 1, '7.23': 1, '5.81': 1, '17.46': 1, '13.1': 1, 'has-ring': 1, 'class': 1, '5.51': 1, '5.48': 1, '4.41': 1, '3.68': 1, '5.97': 1, '1.59': 1, '25.83': 1, '3.89': 1, '4.34': 1, '6.58': 1, '12.04': 1, '13.94': 1}
# {'w': 1196637, 'n': 1003464, 'y': 373971, 'g': 132019, 'o': 111541, 'e': 103373, 'u': 67017, 'p': 54690, 'k': 33676, 'r': 22329, 'l': 9994, 'b': 7365, 'f': 573, 's': 51, 't': 40, 'a': 36, 'x': 20, 'i': 19, 'd': 16, 'h': 12, 'm': 11, 'c': 7, 'z': 6, 'ring-type': 3, 'class': 2, 'spore-print-color': 2, 'is n': 1, '6.31': 1, '12.92': 1, '3.98': 1, '20.07': 1, '7.7': 1, '22.6': 1, '6.09': 1, '17.45': 1, '3.56': 1, '3.37': 1, '4.62': 1, '2.54': 1, '39.51': 1, '18.06': 1, '3.53': 1, '4.49': 1, '1.41': 1, 'e n': 1, '8.49': 1, '2.75': 1, '7.84': 1, '4.75': 1, '26.4': 1, 'is w': 1, '8.32': 1, '23.59': 1, '2.78': 1, '3.13': 1, '33.52': 1, '7.33': 1, '1.75': 1, '4.33': 1}
# {'u': 159373, 'w': 11, 'a': 9, 'f': 8, 'e': 8, 'b': 5, 'c': 5, 'y': 4, 'k': 4, 'g': 4, 'n': 3, 's': 3, 'r': 2, 'd': 2, 'p': 2, 'h': 2, 'i': 2, 'l': 1, 'is None': 1, 't': 1, '21.11': 1, '5.94': 1}
# {'w': 279070, 'y': 30473, 'n': 30039, 'u': 14026, 'k': 13080, 'e': 9169, 'g': 30, 'p': 23, 'r': 14, 'o': 13, 's': 11, 'a': 7, 't': 7, 'd': 6, 'i': 6, 'h': 5, 'c': 4, 'f': 4, 'l': 4, 'b': 3, 'z': 1, '8.25': 1, '2.49': 1, '3.32': 1}
# {'f': 2368820, 't': 747982, 'r': 16, 'h': 13, 'c': 11, 'l': 11, 's': 11, 'p': 11, 'g': 8, 'z': 6, 'e': 6, 'x': 5, 'm': 4, 'y': 3, 'd': 3, 'k': 2, 'o': 2, 'n': 2, 'f has-ring': 1, 'i': 1, '10.3': 1, 'w': 1, 'a': 1}
# {'f': 2477170, 'e': 120006, 'z': 113780, 'l': 73443, 'r': 67909, 'p': 67678, 'g': 63687, 'm': 3992, 't': 98, 'd': 37, 'n': 34, 'x': 32, 'b': 29, 'y': 25, 's': 18, 'k': 18, 'a': 16, 'h': 15, 'w': 14, 'u': 13, 'c': 11, 'o': 9, 'ring-type': 7, 'i': 4, 'does f': 3, 'season': 3, '15': 1, '14': 1, '2.87': 1, 'sp': 1, 'class': 1, 'spore-print-color': 1, '2': 1, '11': 1, '1': 1, '23.6': 1, '4': 1, 'does-bruise-or-bleed': 1, '3.12': 1, '8.25': 1}
# {'k': 107310, 'p': 68237, 'w': 50173, 'n': 22646, 'r': 7975, 'u': 7256, 'g': 3492, 'y': 36, 's': 21, 'c': 16, 'e': 14, 'f': 14, 't': 13, 'a': 13, 'd': 9, 'l': 8, 'b': 5, 'm': 4, 'h': 3, 'o': 3, 'x': 2, 'i': 2, 'veil-color': 2, '10 None': 1, '9 None': 1, '2.49': 1, 'class': 1, '2.62': 1, 'season': 1, '9.55': 1, '6.36': 1, '4.58': 1}
# {'d': 2177573, 'g': 454908, 'l': 171892, 'm': 150969, 'h': 120137, 'w': 18530, 'p': 17180, 'u': 5264, 'e': 55, 's': 52, 'n': 41, 't': 40, 'r': 38, 'y': 34, 'a': 34, 'k': 31, 'c': 26, 'b': 18, 'o': 12, 'f': 11, 'i': 7, 'x': 5, 'z': 5, 'habitat': 5, 'class': 3, 'spore-print-color': 3, 'ring-type': 2, '18.35': 1, '3.68': 1, '2.44': 1, '1.66': 1, '17.38': 1, 'veil-type': 1, '6.75': 1, 'cap-diameter': 1, '7.37': 1, '16.46': 1, '3.11': 1, '6.63': 1, 'is w': 1, '5.62': 1, '7.31': 1, '10.07': 1, '5.56': 1, 'is h': 1, '4': 1, '2.94': 1, 'does-bruise-or-bleed': 1, '9.28': 1, '17.1': 1, '8.09': 1, '2.25': 1}
# {'a': 1543321, 'u': 1153588, 'w': 278189, 's': 141847}

# %% [markdown]
# # Dict Comprehension: {key_expression: value_expression for item in iterable if condition}
#
# # List Expression: [expression for item in iterable if condition]

# %%
filtered_i_list = {col: {value: count for value, count in counts.items() if count >= 10} for col, counts in i_list.items()}
print(filtered_i_list)
# Out:
# {'class': {'p': 1705396, 'e': 1411549}, 'cap-shape': {'x': 1436026, 'f': 676238, 's': 365146, 'b': 318646, 'o': 108835, 'p': 106967, 'c': 104520, 'd': 65, 'e': 60, 'n': 41, 't': 36, 'w': 36, 'g': 34, 'y': 33, 'r': 32, 'a': 30, 'u': 27, 'z': 22, 'l': 21, 'i': 14, 'k': 13}, 'cap-surface': {'t': 460777, 's': 384970, 'y': 327826, 'h': 284460, 'g': 263729, 'd': 206832, 'k': 128875, 'e': 119712, 'i': 113440, 'w': 109840, 'l': 44859, 'n': 96, 'f': 75, 'p': 59, 'u': 49, 'a': 44, 'm': 42, 'o': 39, 'r': 35, 'x': 33, 'c': 31, 'b': 18}, 'cap-color': {'n': 1359542, 'y': 386627, 'w': 379442, 'g': 210825, 'e': 197290, 'o': 178847, 'p': 91838, 'r': 78236, 'u': 73172, 'b': 61313, 'k': 59888, 'l': 39558, 'f': 53, 'd': 48, 's': 39, 'a': 30, 't': 26, 'h': 22, 'm': 14, 'x': 14, 'c': 14, 'i': 13, 'z': 10}, 'does-bruise-or-bleed': {'f': 2569743, 't': 547085, 'w': 14, 'c': 11}, 'gill-attachment': {'a': 646034, 'd': 589236, 'x': 360878, 'e': 301858, 's': 295439, 'p': 279110, 'f': 119953, 'c': 74, 'u': 56, 'w': 37, 't': 36, 'k': 33, 'y': 28, 'i': 25, 'm': 22, 'g': 22, 'b': 21, 'n': 20, 'o': 18, 'h': 18, 'l': 16, 'r': 10}, 'gill-spacing': {'c': 1331054, 'd': 407932, 'f': 119380, 'e': 24, 'a': 17, 's': 16, 'b': 12}, 'gill-color': {'w': 931538, 'n': 543386, 'y': 469464, 'p': 343626, 'g': 212164, 'o': 157119, 'k': 127970, 'f': 119694, 'r': 62799, 'e': 56047, 'b': 47247, 'u': 45399, 'l': 55, 'd': 54, 't': 54, 's': 46, 'x': 35, 'c': 31, 'a': 28, 'h': 24, 'm': 16, 'z': 16}, 'stem-root': {'b': 165801, 's': 116946, 'r': 47803, 'c': 28592, 'f': 597, 'd': 24, 'y': 14, 'g': 12, 'w': 12, 'p': 12, 'k': 11, 't': 10, 'l': 10, 'n': 10}, 'stem-surface': {'s': 327610, 'y': 255500, 'i': 224346, 't': 147974, 'g': 78080, 'k': 73383, 'h': 28283, 'f': 512, 'w': 49, 'd': 48, 'e': 36, 'n': 34, 'x': 26, 'b': 23, 'c': 22, 'l': 20, 'p': 20, 'r': 20, 'u': 16, 'o': 15, 'a': 11}, 'stem-color': {'w': 1196637, 'n': 1003464, 'y': 373971, 'g': 132019, 'o': 111541, 'e': 103373, 'u': 67017, 'p': 54690, 'k': 33676, 'r': 22329, 'l': 9994, 'b': 7365, 'f': 573, 's': 51, 't': 40, 'a': 36, 'x': 20, 'i': 19, 'd': 16, 'h': 12, 'm': 11}, 'veil-type': {'u': 159373, 'w': 11}, 'veil-color': {'w': 279070, 'y': 30473, 'n': 30039, 'u': 14026, 'k': 13080, 'e': 9169, 'g': 30, 'p': 23, 'r': 14, 'o': 13, 's': 11}, 'has-ring': {'f': 2368820, 't': 747982, 'r': 16, 'h': 13, 'c': 11, 'l': 11, 's': 11, 'p': 11}, 'ring-type': {'f': 2477170, 'e': 120006, 'z': 113780, 'l': 73443, 'r': 67909, 'p': 67678, 'g': 63687, 'm': 3992, 't': 98, 'd': 37, 'n': 34, 'x': 32, 'b': 29, 'y': 25, 's': 18, 'k': 18, 'a': 16, 'h': 15, 'w': 14, 'u': 13, 'c': 11}, 'spore-print-color': {'k': 107310, 'p': 68237, 'w': 50173, 'n': 22646, 'r': 7975, 'u': 7256, 'g': 3492, 'y': 36, 's': 21, 'c': 16, 'e': 14, 'f': 14, 't': 13, 'a': 13}, 'habitat': {'d': 2177573, 'g': 454908, 'l': 171892, 'm': 150969, 'h': 120137, 'w': 18530, 'p': 17180, 'u': 5264, 'e': 55, 's': 52, 'n': 41, 't': 40, 'r': 38, 'y': 34, 'a': 34, 'k': 31, 'c': 26, 'b': 18, 'o': 12, 'f': 11}, 'season': {'a': 1543321, 'u': 1153588, 'w': 278189, 's': 141847}}

# %%
filtered_col = list(filtered_i_list.keys())

# %%
for i in filtered_col:
    mushrooms[i] = mushrooms[i].apply(lambda x: x if x in filtered_i_list[i].keys() else np.nan)

# %%
#mushrooms.to_csv('mushrooms.csv', index = False)

# %%
for i in mushrooms.columns:
    print(i)
    print(mushrooms[i].unique())
# Out:
# id
# [      0       1       2 ... 3116942 3116943 3116944]
# class
# ['e' 'p']
# cap-diameter
# [ 8.8   4.51  6.94 ... 38.11 55.63 54.07]
# cap-shape
# ['f' 'x' 'p' 'b' 'o' 'c' 's' 'd' 'e' 'n' nan 'w' 'k' 'l' 't' 'g' 'z' 'a'
#  'r' 'u' 'y' 'i']
# cap-surface
# ['s' 'h' 'y' 'l' 't' 'e' 'g' nan 'd' 'i' 'w' 'k' 'f' 'n' 'r' 'o' 'a' 'u'
#  'p' 'b' 'm' 'x' 'c']
# cap-color
# ['u' 'o' 'b' 'g' 'w' 'n' 'e' 'y' 'r' 'p' 'k' 'l' 'i' 'h' 'd' 's' 'a' 'f'
#  nan 'c' 'x' 'm' 'z' 't']
# does-bruise-or-bleed
# ['f' 't' nan 'w' 'c']
# gill-attachment
# ['a' 'x' 's' 'd' 'e' nan 'f' 'p' 'l' 'm' 'b' 'n' 'g' 'i' 'u' 't' 'o' 'c'
#  'w' 'k' 'r' 'h' 'y']
# gill-spacing
# ['c' nan 'd' 'f' 'b' 'a' 'e' 's']
# gill-color
# ['w' 'n' 'g' 'k' 'y' 'f' 'p' 'o' 'b' 'u' 'e' 'r' 'd' 't' nan 'z' 'h' 'x'
#  's' 'c' 'm' 'l' 'a']
# stem-height
# [ 4.51  4.79  6.85 ... 26.09 47.33 26.53]
# stem-width
# [15.39  6.48  9.93 ... 66.91 79.92 53.44]
# stem-root
# [nan 'b' 'c' 'r' 's' 'f' 'y' 'k' 'd' 'n' 'w' 'p' 't' 'l' 'g']
# stem-surface
# [nan 'y' 's' 't' 'g' 'h' 'k' 'i' 'f' 'l' 'd' 'x' 'w' 'a' 'o' 'c' 'n' 'e'
#  'p' 'b' 'r' 'u']
# stem-color
# ['w' 'o' 'n' 'y' 'e' 'u' 'p' 'f' 'g' 'r' 'k' 'l' 'b' nan 't' 'a' 'h' 'd'
#  's' 'i' 'x' 'm']
# veil-type
# [nan 'u' 'w']
# veil-color
# [nan 'n' 'w' 'k' 'y' 'e' 'u' 'p' 'g' 'r' 's' 'o']
# has-ring
# ['f' 't' 'h' 'r' nan 'c' 'l' 's' 'p']
# ring-type
# ['f' 'z' 'e' nan 'p' 'l' 'g' 'r' 'm' 'y' 'h' 't' 'a' 'd' 's' 'x' 'b' 'u'
#  'n' 'w' 'k' 'c']
# spore-print-color
# [nan 'k' 'w' 'p' 'n' 'r' 'u' 'g' 't' 'f' 'y' 'a' 's' 'e' 'c']
# habitat
# ['d' 'l' 'g' 'h' 'p' 'm' 'u' 'w' 'y' nan 'n' 'a' 's' 'k' 'b' 't' 'c' 'e'
#  'r' 'f' 'o']
# season
# ['a' 'w' 'u' 's']

# %%
filtered_col
# Out:
# ['class',
#  'cap-shape',
#  'cap-surface',
#  'cap-color',
#  'does-bruise-or-bleed',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-color',
#  'stem-root',
#  'stem-surface',
#  'stem-color',
#  'veil-type',
#  'veil-color',
#  'has-ring',
#  'ring-type',
#  'spore-print-color',
#  'habitat',
#  'season']

# %%
mushrooms.shape
# Out:
# (3116945, 22)

# %%
mushrooms.isna().sum()
# Out:
# id                            0
# class                         0
# cap-diameter                  4
# cap-shape                   103
# cap-surface              671104
# cap-color                    84
# does-bruise-or-bleed         92
# gill-attachment          524001
# gill-spacing            1258510
# gill-color                  133
# stem-height                   0
# stem-width                    0
# stem-root               2757091
# stem-surface            1980917
# stem-color                   91
# veil-type               2957561
# veil-color              2740997
# has-ring                     70
# ring-type                128920
# spore-print-color       2849729
# habitat                     100
# season                        0
# dtype: int64

# %%
import numpy as np

def calculate_entropy(column):
    counts = column.value_counts(normalize=False).to_list()
    classes = len(counts)
    total =  3116945 # sum of counts to get the total number of records
    entropy = 0

    for count in counts:
        probability = count / total
        if probability > 0:  # avoid log(0)
            entropy += -probability * np.log2(probability)  # accumulate entropy
        else:
            entropy = 0
    return entropy

# %%
sum
# Out:
# <function sum(iterable, /, start=0)>

# %%
mushrooms
# Out:
#               id  class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0      0          8.80         f           s         u
# 1              1      1          4.51         x           h         o
# 2              2      0          6.94         f           s         b
# 3              3      0          3.88         f           y         g
# 4              4      0          5.85         x           l         w
# ...          ...    ...           ...       ...         ...       ...
# 3116940  3116940      0          9.29         f          -1         n
# 3116941  3116941      0         10.88         s          -1         w
# 3116942  3116942      1          7.82         x           e         e
# 3116943  3116943      0          9.45         p           i         n
# 3116944  3116944      1          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 1                          f               a            c          n  ...
# 2                          f               x            c          w  ...
# 3                          f               s           -1          g  ...
# 4                          f               d           -1          w  ...
# ...                      ...             ...          ...        ...  ...
# 3116940                    t              -1           -1          w  ...
# 3116941                    t               d            c          p  ...
# 3116942                    f               a           -1          w  ...
# 3116943                    t               e           -1          p  ...
# 3116944                    f               d            c          w  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0               -1            -1          w        -1         -1        f
# 1               -1             y          o        -1         -1        t
# 2               -1             s          n        -1         -1        f
# 3               -1            -1          w        -1         -1        f
# 4               -1            -1          w        -1         -1        f
# ...            ...           ...        ...       ...        ...      ...
# 3116940          b            -1          w         u          w        t
# 3116941         -1            -1          w        -1         -1        f
# 3116942         -1            -1          y        -1          w        t
# 3116943         -1             y          w        -1         -1        t
# 3116944         -1            -1          w        -1         -1        f
#
#         ring-type spore-print-color habitat season
# 0               f                -1       d      a
# 1               z                -1       d      w
# 2               f                -1       l      w
# 3               f                -1       d      u
# 4               f                -1       g      a
# ...           ...               ...     ...    ...
# 3116940         g                -1       d      u
# 3116941         f                -1       d      u
# 3116942         z                -1       d      a
# 3116943         p                -1       d      u
# 3116944         f                -1       g      u
#
# [3116945 rows x 22 columns]

# %%
def information_gain(df, feature, target):
    # Calculate the entropy of the entire dataset
    total_entropy = calculate_entropy(df[target])
    
    # Calculate the weighted entropy for each value of the feature
    weighted_entropy = 0
    for value in df[feature].unique():
        subset = df[df[feature] == value]
        subset_entropy = calculate_entropy(subset[target])
        weighted_entropy += (len(subset) / len(df)) * subset_entropy
    
    # Calculate information gain
    ig = total_entropy - weighted_entropy
    return ig


# Calculate information gain for each feature

# %%
cc = []
for i in mushrooms.columns:
    if mushrooms[i].dtype==object:
        cc.append(i)

# %%
cc
# Out:
# ['cap-shape',
#  'cap-surface',
#  'cap-color',
#  'does-bruise-or-bleed',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-color',
#  'stem-root',
#  'stem-surface',
#  'stem-color',
#  'veil-type',
#  'veil-color',
#  'has-ring',
#  'ring-type',
#  'spore-print-color',
#  'habitat',
#  'season']

# %%
for feature in mushrooms[cc]:  # Exclude the targe'Target't column
    ig = information_gain(mushrooms, feature,'class')
    print(f'Information Gain for {feature}: {ig:.4f}')
# Out:
# Information Gain for cap-shape: 0.2742
# Information Gain for cap-surface: 0.5322
# Information Gain for cap-color: 0.3788
# Information Gain for does-bruise-or-bleed: 0.0225
# Information Gain for gill-attachment: 0.4573
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 2
#       1 for feature in mushrooms[cc]:  # Exclude the targe'Target't column
# ----> 2     ig = information_gain(mushrooms, feature,'class')
#       3     print(f'Information Gain for {feature}: {ig:.4f}')
#
# Cell In[59], line 8, in information_gain(df, feature, target)
#       6 weighted_entropy = 0
#       7 for value in df[feature].unique():
# ----> 8     subset = df[df[feature] == value]
#       9     subset_entropy = calculate_entropy(subset[target])
#      10     weighted_entropy += (len(subset) / len(df)) * subset_entropy
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\frame.py:4155, in DataFrame._getitem_bool_array(self, key)
#    4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
# -> 4155 return self._take_with_is_copy(indexer, axis=0)
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\internals\managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\internals\managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:

# %%
for i in mushrooms[cc]:
# Calculate entropy of the column
    entropy = calculate_entropy(mushrooms[i])
    print(f"Entropy and classes of the {i}: {entropy}")
# Out:
# Entropy and classes of the class: 0.9935794251725115
# Entropy and classes of the cap-shape: 2.195280666423383
# Entropy and classes of the cap-surface: 3.280912221684982
# Entropy and classes of the cap-color: 2.73017261091956
# Entropy and classes of the does-bruise-or-bleed: 0.6708084689663235
# Entropy and classes of the gill-attachment: 2.860786937516038
# Entropy and classes of the gill-spacing: 1.6171074926192182
# Entropy and classes of the gill-color: 2.973717952235012
# Entropy and classes of the stem-root: 0.7169413761033208
# Entropy and classes of the stem-surface: 1.86103260600183
# Entropy and classes of the stem-color: 2.3458576313734483
# Entropy and classes of the veil-type: 0.2912514747643015
# Entropy and classes of the veil-color: 0.6980451571309044
# Entropy and classes of the has-ring: 0.7958102778778051
# Entropy and classes of the ring-type: 1.305285847465254
# Entropy and classes of the spore-print-color: 0.6078402058822795
# Entropy and classes of the habitat: 1.4932597808002743
# Entropy and classes of the season: 1.5468365499719572

# %%
mushrooms.shape

# %%
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        mushrooms[i].astype('str')

# %%
mushrooms.columns

# %%
X_tree = X_tree.fillna(-1)

# %%
from scipy.stats import entropy

# %%
entropy(X_tree['cap-shape'])

# %%
entropy(Y_tree)

# %%
Y_tree

# %%
X_tree.columns

# %%
Y_tree = [1.0 if x == 'p' else 0.0 for x in Y_tree]

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Using cached category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\raman\anaconda3\lib\site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\raman\anaconda3\lib\site-packages (from category_encoders) (1.3.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\raman\anaconda3\lib\site-packages (from category_encoders) (1.13.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\raman\anaconda3\lib\site-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\raman\anaconda3\lib\site-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\raman\anaconda3\lib\site-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raman\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raman\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raman\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: six in c:\users\raman\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\raman\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\raman\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\raman\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Using cached category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.4

# %%
import category_encoders as ce

# Initialize the LabelEncoder
encoder = ce.TargetEncoder(handle_missing='return_nan')

# List of columns to encode
columns_to_encode = ['cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 
                     'gill-attachment', 'gill-spacing', 'gill-color', 'stem-root', 
                     'stem-surface', 'stem-color', 'veil-type', 'veil-color', 
                     'has-ring', 'ring-type', 'spore-print-color', 'habitat', 'season']

# %%
# Apply LabelEncoder to each column
for column in columns_to_encode:
    X_tree[column] = encoder.fit_transform(X_tree[column], Y_tree)

print(X_tree.head())

# %%
X_tree.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 X_tree.isna().sum()
#
# NameError: name 'X_tree' is not defined

# %%
p = t.fit(X_tree,Y_tree)

# %%
p

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20, 10), dpi=100)  # Increase the figure size and DPI
plot_tree(p, filled=True, rounded=True, fontsize=10)
plt.show()

# %%
X_tree.info()

# %%
h = p.feature_importances_
l = pd.DataFrame({
    'Feature': X_tree.columns,
    'Importance': h
})

# %%
l.sort_values(by = 'Importance')

# %%
import shap
explainer = shap.TreeExplainer(t)
shap_values = explainer.shap_values(X_tree)
shap.summary_plot(shap_values, X_tree)

# %%
X_tree

# %%
from sklearn.impute import KNNImputer
imp = KNNImputer()

# %%
X_tree = imp.fit_transform(X_tree)

# %%
mushrooms['id'].astype(int)

# %%
columns_float = []
for i in mushrooms.columns:
    if mushrooms[i].dtype != object:
        columns_float.append(i)

# %%
columns_object = []
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        columns_object.append(i)

# %%
columns_object
# Out:
# ['cap-shape',
#  'cap-surface',
#  'cap-color',
#  'does-bruise-or-bleed',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-color',
#  'stem-root',
#  'stem-surface',
#  'stem-color',
#  'veil-type',
#  'veil-color',
#  'has-ring',
#  'ring-type',
#  'spore-print-color',
#  'habitat',
#  'season']

# %%
mushrooms
# Out:
#               id  class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0      0          8.80         f           s         u
# 1              1      1          4.51         x           h         o
# 2              2      0          6.94         f           s         b
# 3              3      0          3.88         f           y         g
# 4              4      0          5.85         x           l         w
# ...          ...    ...           ...       ...         ...       ...
# 3116940  3116940      0          9.29         f          -1         n
# 3116941  3116941      0         10.88         s          -1         w
# 3116942  3116942      1          7.82         x           e         e
# 3116943  3116943      0          9.45         p           i         n
# 3116944  3116944      1          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 1                          f               a            c          n  ...
# 2                          f               x            c          w  ...
# 3                          f               s           -1          g  ...
# 4                          f               d           -1          w  ...
# ...                      ...             ...          ...        ...  ...
# 3116940                    t              -1           -1          w  ...
# 3116941                    t               d            c          p  ...
# 3116942                    f               a           -1          w  ...
# 3116943                    t               e           -1          p  ...
# 3116944                    f               d            c          w  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0               -1            -1          w        -1         -1        f
# 1               -1             y          o        -1         -1        t
# 2               -1             s          n        -1         -1        f
# 3               -1            -1          w        -1         -1        f
# 4               -1            -1          w        -1         -1        f
# ...            ...           ...        ...       ...        ...      ...
# 3116940          b            -1          w         u          w        t
# 3116941         -1            -1          w        -1         -1        f
# 3116942         -1            -1          y        -1          w        t
# 3116943         -1             y          w        -1         -1        t
# 3116944         -1            -1          w        -1         -1        f
#
#         ring-type spore-print-color habitat season
# 0               f                -1       d      a
# 1               z                -1       d      w
# 2               f                -1       l      w
# 3               f                -1       d      u
# 4               f                -1       g      a
# ...           ...               ...     ...    ...
# 3116940         g                -1       d      u
# 3116941         f                -1       d      u
# 3116942         z                -1       d      a
# 3116943         p                -1       d      u
# 3116944         f                -1       g      u
#
# [3116945 rows x 22 columns]

# %%
mushrooms[mushrooms['gill-spacing'].notna()]
# Out:
#               id  class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0      0          8.80         f           s         u
# 1              1      1          4.51         x           h         o
# 2              2      0          6.94         f           s         b
# 3              3      0          3.88         f           y         g
# 4              4      0          5.85         x           l         w
# ...          ...    ...           ...       ...         ...       ...
# 3116940  3116940      0          9.29         f          -1         n
# 3116941  3116941      0         10.88         s          -1         w
# 3116942  3116942      1          7.82         x           e         e
# 3116943  3116943      0          9.45         p           i         n
# 3116944  3116944      1          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 1                          f               a            c          n  ...
# 2                          f               x            c          w  ...
# 3                          f               s           -1          g  ...
# 4                          f               d           -1          w  ...
# ...                      ...             ...          ...        ...  ...
# 3116940                    t              -1           -1          w  ...
# 3116941                    t               d            c          p  ...
# 3116942                    f               a           -1          w  ...
# 3116943                    t               e           -1          p  ...
# 3116944                    f               d            c          w  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0               -1            -1          w        -1         -1        f
# 1               -1             y          o        -1         -1        t
# 2               -1             s          n        -1         -1        f
# 3               -1            -1          w        -1         -1        f
# 4               -1            -1          w        -1         -1        f
# ...            ...           ...        ...       ...        ...      ...
# 3116940          b            -1          w         u          w        t
# 3116941         -1            -1          w        -1         -1        f
# 3116942         -1            -1          y        -1          w        t
# 3116943         -1             y          w        -1         -1        t
# 3116944         -1            -1          w        -1         -1        f
#
#         ring-type spore-print-color habitat season
# 0               f                -1       d      a
# 1               z                -1       d      w
# 2               f                -1       l      w
# 3               f                -1       d      u
# 4               f                -1       g      a
# ...           ...               ...     ...    ...
# 3116940         g                -1       d      u
# 3116941         f                -1       d      u
# 3116942         z                -1       d      a
# 3116943         p                -1       d      u
# 3116944         f                -1       g      u
#
# [3116945 rows x 22 columns]

# %%
mushrooms.isna().sum()
# Out:
# id                      0
# class                   0
# cap-diameter            0
# cap-shape               0
# cap-surface             0
# cap-color               0
# does-bruise-or-bleed    0
# gill-attachment         0
# gill-spacing            0
# gill-color              0
# stem-height             0
# stem-width              0
# stem-root               0
# stem-surface            0
# stem-color              0
# veil-type               0
# veil-color              0
# has-ring                0
# ring-type               0
# spore-print-color       0
# habitat                 0
# season                  0
# dtype: int64

# %%
mushrooms=mushrooms.drop('index', axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 mushrooms=mushrooms.drop('index', axis =1)
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\raman\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
mushrooms
# Out:
#               id  class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0      0          8.80         f           s         u
# 1              1      1          4.51         x           h         o
# 2              2      0          6.94         f           s         b
# 3              3      0          3.88         f           y         g
# 4              4      0          5.85         x           l         w
# ...          ...    ...           ...       ...         ...       ...
# 3116940  3116940      0          9.29         f          -1         n
# 3116941  3116941      0         10.88         s          -1         w
# 3116942  3116942      1          7.82         x           e         e
# 3116943  3116943      0          9.45         p           i         n
# 3116944  3116944      1          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 1                          f               a            c          n  ...
# 2                          f               x            c          w  ...
# 3                          f               s           -1          g  ...
# 4                          f               d           -1          w  ...
# ...                      ...             ...          ...        ...  ...
# 3116940                    t              -1           -1          w  ...
# 3116941                    t               d            c          p  ...
# 3116942                    f               a           -1          w  ...
# 3116943                    t               e           -1          p  ...
# 3116944                    f               d            c          w  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0               -1            -1          w        -1         -1        f
# 1               -1             y          o        -1         -1        t
# 2               -1             s          n        -1         -1        f
# 3               -1            -1          w        -1         -1        f
# 4               -1            -1          w        -1         -1        f
# ...            ...           ...        ...       ...        ...      ...
# 3116940          b            -1          w         u          w        t
# 3116941         -1            -1          w        -1         -1        f
# 3116942         -1            -1          y        -1          w        t
# 3116943         -1             y          w        -1         -1        t
# 3116944         -1            -1          w        -1         -1        f
#
#         ring-type spore-print-color habitat season
# 0               f                -1       d      a
# 1               z                -1       d      w
# 2               f                -1       l      w
# 3               f                -1       d      u
# 4               f                -1       g      a
# ...           ...               ...     ...    ...
# 3116940         g                -1       d      u
# 3116941         f                -1       d      u
# 3116942         z                -1       d      a
# 3116943         p                -1       d      u
# 3116944         f                -1       g      u
#
# [3116945 rows x 22 columns]

# %%
mushrooms['cap-diameter'].fillna(0, inplace = True)

# %%
mushrooms.fillna('Missing',inplace = True)

# %%
poisnous = mushrooms[mushrooms['class']=='p']

# %%
poisnous

# %%
poisnous['cap-diameter'].mean()

# %%
poisnous['cap-diameter'].median()

# %%
edible = mushrooms[mushrooms['class']=='e']

# %%
edible['cap-diameter'].mean()

# %%
edible['cap-diameter'].median()

# %%
mushrooms

# %%
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        layout = go.Layout(title = f'Poisnous/edible-{i}',xaxis = dict(title=f'feature name {i}'),
                           yaxis = dict(title='Count'),hovermode = 'closest'
                           )
        trace0 = go.Bar(x=edible[i],y=edible[i].value_counts(), name = 'edible', marker = {'color':'blue'})
        trace1 = go.Bar(x=poisnous[i],y=poisnous[i].value_counts(), name = 'poisnous', marker = {'color':'red'})
        data = [trace0, trace1]
        fig = go.Figure(data = data, layout = layout)
        pyo.plot(fig)

# %%
mushrooms
# Out:
#               id  class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0      0          8.80         f           s         u
# 1              1      1          4.51         x           h         o
# 2              2      0          6.94         f           s         b
# 3              3      0          3.88         f           y         g
# 4              4      0          5.85         x           l         w
# ...          ...    ...           ...       ...         ...       ...
# 3116940  3116940      0          9.29         f          -1         n
# 3116941  3116941      0         10.88         s          -1         w
# 3116942  3116942      1          7.82         x           e         e
# 3116943  3116943      0          9.45         p           i         n
# 3116944  3116944      1          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 1                          f               a            c          n  ...
# 2                          f               x            c          w  ...
# 3                          f               s           -1          g  ...
# 4                          f               d           -1          w  ...
# ...                      ...             ...          ...        ...  ...
# 3116940                    t              -1           -1          w  ...
# 3116941                    t               d            c          p  ...
# 3116942                    f               a           -1          w  ...
# 3116943                    t               e           -1          p  ...
# 3116944                    f               d            c          w  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0               -1            -1          w        -1         -1        f
# 1               -1             y          o        -1         -1        t
# 2               -1             s          n        -1         -1        f
# 3               -1            -1          w        -1         -1        f
# 4               -1            -1          w        -1         -1        f
# ...            ...           ...        ...       ...        ...      ...
# 3116940          b            -1          w         u          w        t
# 3116941         -1            -1          w        -1         -1        f
# 3116942         -1            -1          y        -1          w        t
# 3116943         -1             y          w        -1         -1        t
# 3116944         -1            -1          w        -1         -1        f
#
#         ring-type spore-print-color habitat season
# 0               f                -1       d      a
# 1               z                -1       d      w
# 2               f                -1       l      w
# 3               f                -1       d      u
# 4               f                -1       g      a
# ...           ...               ...     ...    ...
# 3116940         g                -1       d      u
# 3116941         f                -1       d      u
# 3116942         z                -1       d      a
# 3116943         p                -1       d      u
# 3116944         f                -1       g      u
#
# [3116945 rows x 22 columns]

# %%
mushrooms

# %%
#mushrooms['cap-diameter'] = mushrooms['cap-diameter'].fillna(mushrooms['cap-diameter'].mean())

# %%
mushrooms.dtypes

# %%
mushrooms

# %%
for i in mushrooms.columns:
    if mushrooms[i].dtype == object:
        layout = go.Layout(title = f'Poisnous/edible-{i}',xaxis = dict(title=f'feature name {i}'),
                           yaxis = dict(title='Count'),hovermode = 'closest'
                           )
        trace0 = go.Bar(x=mushrooms[i],y=mushrooms[i][mushrooms['class']=='e'].value_counts(), name = 'edible', marker = {'color':'blue'})
        trace1 = go.Bar(x=mushrooms[i],y=mushrooms[i][mushrooms['class']=='p'].value_counts(), name = 'poisnous', marker = {'color':'red'})

        data = [trace0,trace1]
        fig = go.Figure(data = data, layout = layout)
        pyo.plot(fig)

# %%
mushrooms.columns

# %%
mushrooms

# %%
mushrooms

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.preprocessing import TargetEncoder

# %%
mushrooms['class'] = mushrooms['class'].apply(lambda x: 1 if x=='p' else 0)

# %%
from scipy.stats import pointbiserialr

# %%
mushrooms=mushrooms.fillna(-1)

# %%
correlation_coefficient, p_value = pointbiserialr(mushrooms['class'], mushrooms['cap-diameter'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 correlation_coefficient, p_value = pointbiserialr(mushrooms['class'], mushrooms['cap-diameter'])
#
# File c:\Users\raman\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:5535, in pointbiserialr(x, y)
#    5447 def pointbiserialr(x, y):
#    5448     r"""Calculate a point biserial correlation coefficient and its p-value.
#    5449
#    5450     The point biserial correlation is used to measure the relationship
#    (...)
#    5533
#    5534     """
# -> 5535     rpb, prob = pearsonr(x, y)
#    5536     # create result object with alias for backward compatibility
#    5537     res = SignificanceResult(rpb, prob)
#
# File c:\Users\raman\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:4794, in pearsonr(x, y, alternative, method)
#    4790 # Unlike np.linalg.norm or the expression sqrt((xm*xm).sum()),
#    4791 # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    4792 # [-5e210, 5e210, 3e200, -3e200]
#    4793 normxm = linalg.norm(xm)
# -> 4794 normym = linalg.norm(ym)
#    4796 threshold = 1e-13
#    4797 if normxm < threshold*abs(xmean) or normym < threshold*abs(ymean):
#    4798     # If all the values in x (likewise y) are very close to the mean,
#    4799     # the loss of precision that occurs in the subtraction xm = x - xmean
#    4800     # might result in large errors in r.
#
# File c:\Users\raman\anaconda3\lib\site-packages\scipy\linalg\_misc.py:146, in norm(a, ord, axis, keepdims, check_finite)
#     144 # Differs from numpy only in non-finite handling and the use of blas.
#     145 if check_finite:
# --> 146     a = np.asarray_chkfinite(a)
#     147 else:
#     148     a = np.asarray(a)
#
# File c:\Users\raman\anaconda3\lib\site-packages\numpy\lib\function_base.py:630, in asarray_chkfinite(a, dtype, order)
#     628 a = asarray(a, dtype=dtype, order=order)
#     629 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 630     raise ValueError(
#     631         "array must not contain infs or NaNs")
#     632 return a
#
# ValueError: array must not contain infs or NaNs

# %%
correlation_coefficient, p_value
# Out:
# (-0.16262678971399108, 0.0)

# %%
correlation_coefficient, p_value = pointbiserialr(mushrooms['class'], mushrooms['stem-height'])

# %%
correlation_coefficient, p_value
# Out:
# (-0.04974044110354139, 0.0)

# %%
correlation_coefficient, p_value = pointbiserialr(mushrooms['class'], mushrooms['stem-width'])

# %%
correlation_coefficient, p_value
# Out:
# (-0.16980695567678847, 0.0)

# %%
Y = mushrooms['class'].apply(lambda x: 1 if x=='p' else 0)
X = mushrooms.iloc[:,2:]

# %%
X

# %%
from sklearn.preprocessing import TargetEncoder
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from lightgbm import LGBMClassifier
from sklearn.pipeline import Pipeline

mc_cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=42)
params = {
    'objective': 'binary',
    'metric': 'auc',
    'boosting_type': 'gbdt',  # Gradient Boosting Decision Tree
    'num_leaves': 31,         # Number of leaves in one tree
    'learning_rate': 0.05,
      # Randomly select a fraction of features to build each tree
}

# %%
encder = TargetEncoder(smooth = 'auto')

# %%
pipeline = Pipeline([('target_encoder', encder),
    ('lgbm', LGBMClassifier(**params))])
pipeline.fit(X,Y)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Contains only one class
# [LightGBM] [Info] Number of positive: 0, number of negative: 3116945
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 3116945, number of used features: 0
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.000000 -> initscore=-34.538776
# [LightGBM] [Info] Start training from score -34.538776
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Pipeline(steps=[('target_encoder', TargetEncoder()),
#                 ('lgbm',
#                  LGBMClassifier(learning_rate=0.05, metric='auc',
#                                 objective='binary'))])

# %%
pipeline.predict(X)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# After loading the model
target_encoder = pipeline.named_steps['target_encoder']
# Refit the encoder with the original training data
target_encoder.fit(X, Y)
# Out:
# TargetEncoder()

# %%
input_df
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0           5.0      bell      smooth     brown                  yes
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0            free        close      black         10.0         2.0   bulbous
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0       smooth      white   partial      white      yes      zone
#
#   spore-print-color   habitat  season
# 0            purple  woodland  summer

# %%
mushrooms.columns
# Out:
# Index(['id', 'class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')

# %%
pipeline.predict(input_df)
# Out:
# array([0], dtype=int64)

# %%
import pickle

# %%
with open("pipeline.pkl", "wb") as f:
    pickle.dump(pipeline, f)

# %%
with open("pipeline.pkl", "rb") as f:
    loaded_pipeline = pickle.load(f)

# %%
'id', 'class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
       'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
       'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
       'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
       'habitat', 'season'

# %%
sample_input = {
    "cap-diameter": 5.0,
    "cap-shape": "bell",
    "cap-surface": "smooth",
    "cap-color": "brown",
    "does-bruise-or-bleed": "yes",
    "gill-attachment": "free",
    "gill-spacing": "close",
    "gill-color": "black",
    "stem-height": 10.0,
    "stem-width": 2.0,
    "stem-root": "bulbous",
    "stem-surface": "smooth",
    "stem-color": "white",
    "veil-type": "partial",
    "veil-color": "white",
    "has-ring": "yes",
    "ring-type": "zone",
    "spore-print-color": "purple",
    "habitat": "woodland",
    "season": "summer"
}

# %%
sample_input
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 sample_input
#
# NameError: name 'sample_input' is not defined

# %%
mushrooms = mushrooms[mushrooms['class']=='e']

# %%
mushrooms
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# 6              6     e          9.65         p           y         w
# ...          ...   ...           ...       ...         ...       ...
# 3116932  3116932     e          4.03         x         NaN         w
# 3116933  3116933     e          8.44         f           s         w
# 3116940  3116940     e          9.29         f         NaN         n
# 3116941  3116941     e         10.88         s         NaN         w
# 3116943  3116943     e          9.45         p           i         n
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 2                          f               x            c          w  ...
# 3                          f               s          NaN          g  ...
# 4                          f               d          NaN          w  ...
# 6                          f               e            c          k  ...
# ...                      ...             ...          ...        ...  ...
# 3116932                    f               x            c          w  ...
# 3116933                    f               s            c          w  ...
# 3116940                    t             NaN          NaN          w  ...
# 3116941                    t               d            c          p  ...
# 3116943                    t               e          NaN          p  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0              NaN           NaN          w       NaN        NaN        f
# 2              NaN             s          n       NaN        NaN        f
# 3              NaN           NaN          w       NaN        NaN        f
# 4              NaN           NaN          w       NaN        NaN        f
# 6              NaN             s          w       NaN        NaN        t
# ...            ...           ...        ...       ...        ...      ...
# 3116932          b           NaN          n       NaN          w        t
# 3116933        NaN           NaN          w       NaN        NaN        f
# 3116940          b           NaN          w         u          w        t
# 3116941        NaN           NaN          w       NaN        NaN        f
# 3116943        NaN             y          w       NaN        NaN        t
#
#         ring-type spore-print-color habitat season
# 0               f               NaN       d      a
# 2               f               NaN       l      w
# 3               f               NaN       d      u
# 4               f               NaN       g      a
# 6               e               NaN       g      w
# ...           ...               ...     ...    ...
# 3116932       NaN               NaN       g      s
# 3116933         f               NaN       m      s
# 3116940         g               NaN       d      u
# 3116941         f               NaN       d      u
# 3116943         p               NaN       d      u
#
# [1411549 rows x 22 columns]

# %%
X
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0                8.80         f           s         u                    f
# 1                4.51         x           h         o                    f
# 2                6.94         f           s         b                    f
# 3                3.88         f           y         g                    f
# 4                5.85         x           l         w                    f
# ...               ...       ...         ...       ...                  ...
# 3116940          9.29         f         NaN         n                    t
# 3116941         10.88         s         NaN         w                    t
# 3116942          7.82         x           e         e                    f
# 3116943          9.45         p           i         n                    t
# 3116944          3.20         x           s         g                    f
#
#         gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# 0                     a            c          w         4.51       15.39
# 1                     a            c          n         4.79        6.48
# 2                     x            c          w         6.85        9.93
# 3                     s          NaN          g         4.16        6.53
# 4                     d          NaN          w         3.37        8.36
# ...                 ...          ...        ...          ...         ...
# 3116940             NaN          NaN          w        12.14       18.81
# 3116941               d            c          p         6.65       26.97
# 3116942               a          NaN          w         9.51       11.06
# 3116943               e          NaN          p         9.13       17.77
# 3116944               d            c          w         2.82        7.79
#
#         stem-root stem-surface stem-color veil-type veil-color has-ring  \
# 0             NaN          NaN          w       NaN        NaN        f
# 1             NaN            y          o       NaN        NaN        t
# 2             NaN            s          n       NaN        NaN        f
# 3             NaN          NaN          w       NaN        NaN        f
# 4             NaN          NaN          w       NaN        NaN        f
# ...           ...          ...        ...       ...        ...      ...
# 3116940         b          NaN          w         u          w        t
# 3116941       NaN          NaN          w       NaN        NaN        f
# 3116942       NaN          NaN          y       NaN          w        t
# 3116943       NaN            y          w       NaN        NaN        t
# 3116944       NaN          NaN          w       NaN        NaN        f
#
#         ring-type spore-print-color habitat season
# 0               f               NaN       d      a
# 1               z               NaN       d      w
# 2               f               NaN       l      w
# 3               f               NaN       d      u
# 4               f               NaN       g      a
# ...           ...               ...     ...    ...
# 3116940         g               NaN       d      u
# 3116941         f               NaN       d      u
# 3116942         z               NaN       d      a
# 3116943         p               NaN       d      u
# 3116944         f               NaN       g      u
#
# [3116945 rows x 20 columns]

# %%
X.fillna

# %%
a = loaded_pipeline.predict(X)

# %%
a
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import recall_score

# %%
X
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0                8.80         f           s         u                    f
# 1                4.51         x           h         o                    f
# 2                6.94         f           s         b                    f
# 3                3.88         f           y         g                    f
# 4                5.85         x           l         w                    f
# ...               ...       ...         ...       ...                  ...
# 3116940          9.29         f         NaN         n                    t
# 3116941         10.88         s         NaN         w                    t
# 3116942          7.82         x           e         e                    f
# 3116943          9.45         p           i         n                    t
# 3116944          3.20         x           s         g                    f
#
#         gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# 0                     a            c          w         4.51       15.39
# 1                     a            c          n         4.79        6.48
# 2                     x            c          w         6.85        9.93
# 3                     s          NaN          g         4.16        6.53
# 4                     d          NaN          w         3.37        8.36
# ...                 ...          ...        ...          ...         ...
# 3116940             NaN          NaN          w        12.14       18.81
# 3116941               d            c          p         6.65       26.97
# 3116942               a          NaN          w         9.51       11.06
# 3116943               e          NaN          p         9.13       17.77
# 3116944               d            c          w         2.82        7.79
#
#         stem-root stem-surface stem-color veil-type veil-color has-ring  \
# 0             NaN          NaN          w       NaN        NaN        f
# 1             NaN            y          o       NaN        NaN        t
# 2             NaN            s          n       NaN        NaN        f
# 3             NaN          NaN          w       NaN        NaN        f
# 4             NaN          NaN          w       NaN        NaN        f
# ...           ...          ...        ...       ...        ...      ...
# 3116940         b          NaN          w         u          w        t
# 3116941       NaN          NaN          w       NaN        NaN        f
# 3116942       NaN          NaN          y       NaN          w        t
# 3116943       NaN            y          w       NaN        NaN        t
# 3116944       NaN          NaN          w       NaN        NaN        f
#
#         ring-type spore-print-color habitat season
# 0               f               NaN       d      a
# 1               z               NaN       d      w
# 2               f               NaN       l      w
# 3               f               NaN       d      u
# 4               f               NaN       g      a
# ...           ...               ...     ...    ...
# 3116940         g               NaN       d      u
# 3116941         f               NaN       d      u
# 3116942         z               NaN       d      a
# 3116943         p               NaN       d      u
# 3116944         f               NaN       g      u
#
# [3116945 rows x 20 columns]

# %%
recall_score(Y,a)
# Out:
# c:\Users\raman\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.0

# %%
X
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0                8.80         f           s         u                    f
# 1                4.51         x           h         o                    f
# 2                6.94         f           s         b                    f
# 3                3.88         f           y         g                    f
# 4                5.85         x           l         w                    f
# ...               ...       ...         ...       ...                  ...
# 3116940          9.29         f         NaN         n                    t
# 3116941         10.88         s         NaN         w                    t
# 3116942          7.82         x           e         e                    f
# 3116943          9.45         p           i         n                    t
# 3116944          3.20         x           s         g                    f
#
#         gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# 0                     a            c          w         4.51       15.39
# 1                     a            c          n         4.79        6.48
# 2                     x            c          w         6.85        9.93
# 3                     s          NaN          g         4.16        6.53
# 4                     d          NaN          w         3.37        8.36
# ...                 ...          ...        ...          ...         ...
# 3116940             NaN          NaN          w        12.14       18.81
# 3116941               d            c          p         6.65       26.97
# 3116942               a          NaN          w         9.51       11.06
# 3116943               e          NaN          p         9.13       17.77
# 3116944               d            c          w         2.82        7.79
#
#         stem-root stem-surface stem-color veil-type veil-color has-ring  \
# 0             NaN          NaN          w       NaN        NaN        f
# 1             NaN            y          o       NaN        NaN        t
# 2             NaN            s          n       NaN        NaN        f
# 3             NaN          NaN          w       NaN        NaN        f
# 4             NaN          NaN          w       NaN        NaN        f
# ...           ...          ...        ...       ...        ...      ...
# 3116940         b          NaN          w         u          w        t
# 3116941       NaN          NaN          w       NaN        NaN        f
# 3116942       NaN          NaN          y       NaN          w        t
# 3116943       NaN            y          w       NaN        NaN        t
# 3116944       NaN          NaN          w       NaN        NaN        f
#
#         ring-type spore-print-color habitat season
# 0               f               NaN       d      a
# 1               z               NaN       d      w
# 2               f               NaN       l      w
# 3               f               NaN       d      u
# 4               f               NaN       g      a
# ...           ...               ...     ...    ...
# 3116940         g               NaN       d      u
# 3116941         f               NaN       d      u
# 3116942         z               NaN       d      a
# 3116943         p               NaN       d      u
# 3116944         f               NaN       g      u
#
# [3116945 rows x 20 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
a
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a.shape
# Out:
# (1411549,)

# %%
np.sum(a == 1)
# Out:
# 34078

# %%
accuracy_score(Y,a)
# Out:
# 0.9758577279286798

# %%
a[0]
# Out:
# 0

# %%
import pandas as pd

# %%
 input_array = pd.DataFrame({
            "cap_diameter": [input_data.cap_diameter],
            "cap_shape": [input_data.cap_shape],
            "cap_surface": [input_data.cap_surface],
            "cap_color": [input_data.cap_color],
            "does_bruise_or_bleed": [input_data.does_bruise_or_bleed],
            "gill_attachment": [input_data.gill_attachment],
            "gill_spacing": [input_data.gill_spacing],
            "gill_color": [input_data.gill_color],
            "stem_height": [input_data.stem_height],
            "stem_width": [input_data.stem_width],
            "stem_root": [input_data.stem_root],
            "stem_surface": [input_data.stem_surface],
            "stem_color": [input_data.stem_color],
            "veil_type": [input_data.veil_type],
            "veil_color": [input_data.veil_color],
            "has_ring": [input_data.has_ring],
            "ring_type": [input_data.ring_type],
            "spore_print_color": [input_data.spore_print_color],
            "habitat": [input_data.habitat],
            "season": [input_data.season]

# %%
input_df = pd.DataFrame([sample_input])  # Correctly formatted as 2D

# %%
import requests

url = "https://raman12345-bzg7bhdkfbh4beft.centralindia-01.azurewebsites.net/predict"

# Define the data dictionary
input_data = {
    "cap-diameter": 5.0,
    "cap-shape": "c",
    "cap-surface": "c",
    "cap-color": "c",
    "does-bruise-or-bleed": "c",
    "gill-attachment": "c",
    "gill-spacing": "c",
    "gill-color": "c",
    "stem-height": 10.0,
    "stem-width": 1.0,
    "stem-root": "c",
    "stem-surface": "c",
    "stem-color": "c",
    "veil-type": "c",
    "veil-color": "c",
    "has-ring": "c",
    "ring-type": "c",
    "spore-print-color": "c",
    "habitat": "c",
    "season": "c"
}

# Send the POST request


try:
    response = requests.post(url, json=input_data)
    response.raise_for_status()  # Raises an error for HTTP errors
    print(response.json())  # Print the actual response content
except requests.exceptions.HTTPError as err:
    print(f"HTTP error occurred: {err}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# {'prediction': 'Poisonous'}

# %%
mushrooms
# Out:
#               id  class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0      0          8.80         f           s         u
# 1              1      1          4.51         x           h         o
# 2              2      0          6.94         f           s         b
# 3              3      0          3.88         f           y         g
# 4              4      0          5.85         x           l         w
# ...          ...    ...           ...       ...         ...       ...
# 3116940  3116940      0          9.29         f         NaN         n
# 3116941  3116941      0         10.88         s         NaN         w
# 3116942  3116942      1          7.82         x           e         e
# 3116943  3116943      0          9.45         p           i         n
# 3116944  3116944      1          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# 0                          f               a            c          w  ...
# 1                          f               a            c          n  ...
# 2                          f               x            c          w  ...
# 3                          f               s          NaN          g  ...
# 4                          f               d          NaN          w  ...
# ...                      ...             ...          ...        ...  ...
# 3116940                    t             NaN          NaN          w  ...
# 3116941                    t               d            c          p  ...
# 3116942                    f               a          NaN          w  ...
# 3116943                    t               e          NaN          p  ...
# 3116944                    f               d            c          w  ...
#
#          stem-root  stem-surface stem-color veil-type veil-color has-ring  \
# 0              NaN           NaN          w       NaN        NaN        f
# 1              NaN             y          o       NaN        NaN        t
# 2              NaN             s          n       NaN        NaN        f
# 3              NaN           NaN          w       NaN        NaN        f
# 4              NaN           NaN          w       NaN        NaN        f
# ...            ...           ...        ...       ...        ...      ...
# 3116940          b           NaN          w         u          w        t
# 3116941        NaN           NaN          w       NaN        NaN        f
# 3116942        NaN           NaN          y       NaN          w        t
# 3116943        NaN             y          w       NaN        NaN        t
# 3116944        NaN           NaN          w       NaN        NaN        f
#
#         ring-type spore-print-color habitat season
# 0               f               NaN       d      a
# 1               z               NaN       d      w
# 2               f               NaN       l      w
# 3               f               NaN       d      u
# 4               f               NaN       g      a
# ...           ...               ...     ...    ...
# 3116940         g               NaN       d      u
# 3116941         f               NaN       d      u
# 3116942         z               NaN       d      a
# 3116943         p               NaN       d      u
# 3116944         f               NaN       g      u
#
# [3116945 rows x 22 columns]

# %%
row_dict = mushrooms.iloc[1].to_dict()

# %%
print(row_dict)
# Out:
# {'id': 1, 'class': 1, 'cap-diameter': 4.51, 'cap-shape': 'x', 'cap-surface': 'h', 'cap-color': 'o', 'does-bruise-or-bleed': 'f', 'gill-attachment': 'a', 'gill-spacing': 'c', 'gill-color': 'n', 'stem-height': 4.79, 'stem-width': 6.48, 'stem-root': nan, 'stem-surface': 'y', 'stem-color': 'o', 'veil-type': nan, 'veil-color': nan, 'has-ring': 't', 'ring-type': 'z', 'spore-print-color': nan, 'habitat': 'd', 'season': 'w'}

# %%
import pickle
model_path = "models/pipeline.pkl"
with open(model_path, "rb") as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pickle
#       2 model_path = "models/pipeline.pkl"
# ----> 3 with open(model_path, "rb") as f:
#       4     model = pickle.load(f)
#
# File c:\Users\raman\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/pipeline.pkl'
